# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import meteva.base as meb
import meteva.method as mem
import meteva.product as mpd
import numpy as np
import datetime
import copy
import matplotlib.pyplot as plt
import time
import pandas as pd
import math
import matplotlib as mpl

# %%
sta_all =pd.read_hdf(r"O:\data\hdf\combined\rain01/week.h5","df")
sta_all_c = meb.sele_by_para(sta_all,value = [0,1000])

# %%
id_dict = meb.tool.station_tools.find_station_id_by_city_name("北京")
ids= np.array(list(id_dict.values()))
ids = ids[ids<60000]
ids = ids.tolist()

# %%
sta_part = meb.sele_by_para(sta_all,id=[54511],time_range = ["2020052009","2020052118"])

# %%
mpd.time_list_mesh_rain01h(sta_part,save_dir = r"H:\task\文字材料\每周讨论\0522",plot_error = True,show = True)
# Out:
# 图片已保存至H:\task\文字材料\每周讨论\0522/gmosrr_54511.png

# %%
sta_part = meb.sele_by_para(sta_all,id=54511)

# %%
mpd.time_list_mesh_rain01h(sta_part,save_dir = r"H:\task\文字材料\每周讨论\0522",plot_error = False,show = True)

# %%
rain24 = meb.fun.accumulate_time(sta_part,24)

# %%
sta_part
