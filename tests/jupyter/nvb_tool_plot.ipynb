# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import nmc_verification.nmc_vf_base as nvb

# %%
grid0 = nvb.grid([70,140,1],[15,55,1])
grd = nvb.io.read_griddata_from_nc(r"H:\test_data\ecmwf\temp_2m\19111608.024.nc",grid = grid0)
print(grd)
# Out:
# <xarray.DataArray 'data0' (member: 1, level: 1, time: 1, dtime: 1, lat: 41, lon: 71)>
# array([[[[[[25.937511, ..., 28.250004],
#            ...,
#            [-2.374992, ..., -3.187485]]]]]])
# Coordinates:
#   * member   (member) int32 0
#   * level    (level) int32 -2147483647
#   * time     (time) datetime64[ns] 2001-03-01
#   * dtime    (dtime) int32 0
#   * lat      (lat) int32 15 16 17 18 19 20 21 22 23 ... 48 49 50 51 52 53 54 55
#   * lon      (lon) int32 70 71 72 73 74 75 76 77 ... 134 135 136 137 138 139 140
# Attributes:
#     dtime_type:  hour

# %%
nvb.tool.plot_tools.contourf_2d_grid(grd)

# %%
nvb.tool.plot_tools.pcolormesh_2d_grid(grd)
