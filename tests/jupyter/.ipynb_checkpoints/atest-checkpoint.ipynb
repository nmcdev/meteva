# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import meteva.base as meb
import meteva.method as mem
import meteva.product as mpd
import numpy as np
import datetime
import copy
import matplotlib.pyplot as plt
import pandas as pd

# %%
sta_all = pd.read_hdf(r"H:\test_data\input\mpd\program_error_scatter_test.h5","df")

# %%
mpd.time_list_line(sta_all,s = {"id":54511})

# %%
mpd.plot(sta_all,mem.scatter_regress,s = {"ob_time":"2020040808"})
# Out:
# []

# %%
mpd.me_scatter(sta_all,threshold = 2)
# Out:
# 误差绝对值前1的站点：
# id:57359   lon:110.73  lat:31.35 value:-6.288272
# 误差绝对值前1的站点：
# id:57355   lon:110.37  lat:31.03 value:-6.654348

# %%
mpd.me_scatter(sta_all,s={"member":["ob","scmoc"]})
# Out:
# error infomation: scmoc is not a data column
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6e09a2f3d7c1> in <module>
# ----> 1 mpd.me_scatter(sta_all,s={"member":["ob","scmoc"]})
#
# h:\task\develop\python\git\meteva\meteva\product\program\error_ana_scatter.py in me_scatter(sta_ob_and_fos, s, g, gll, group_name_list, save_dir, save_path, show, print_max, threshold, add_county_line, map_extend, title)
#     166     for k in range(g_num):
#     167         sta_ob_and_fos_g1 = sta_ob_and_fos_list[k]
# --> 168         _,_,rmse_sta = meteva.product.score(sta_ob_and_fos_g1,meteva.method.me,g="id")
#     169         values = rmse_sta.values[:, 6:]
#     170         mean_value = np.mean(np.abs(values))
#
# h:\task\develop\python\git\meteva\meteva\product\program\score.py in score(sta_ob_and_fos0, method, s, g, gll, para1, para2)
# ...

# %%
sta_all

# %%
mpd.error_boxplot(sta_all,g = "time")

# %%
sta1 = sta_all.copy()

# %%
sta1["time"] = sta1["time"] - datetime.timedelta(days = 1)

# %%
mpd.error_boxplot(sta1,g = "time")

# %%
para= {
    "ip_port_file":r"H:\test_data\input\meb\ip_port.txt",
    "local_binary_dir":"O:/data/mdfs",
    "local_sta_dir": "O:/data/sta",
    "local_grid_dir":"O:/data/grid",
    "max_save_day":7,
    }

# %%
dir_ob = "SURFACE\QC_BY_FSOL\TMP_ALL_STATION/YYYYMMDDHH0000.000"
now = datetime.datetime.now()
today = datetime.datetime(now.year,now.month,now.day,8,0)
station_alt = meb.read_station(meb.station_国家站)
station = station_alt.copy()
station["data0"] = meb.IV
id_dict = {"北京":54511,"哈尔滨":50953, "武汉":57494,"广州":59287}
id_list = []
for key in id_dict.keys():
    id_list.append(id_dict[key])
station_city = meb.in_id_list(station,[57842])
veri_day_count =7
time1 = today - datetime.timedelta(days = veri_day_count)
tweek_ago = time1 - datetime.timedelta(days = veri_day_count)

# %%
#读取模式数据
dir_scmoc = r"NWFD_SCMOC\RAIN03/YYMMDDHH.TTT"
scmoc_list = []
time2 = time1 
while time2 <= now:
    for dh in range(3,73,3):
        path = meb.tool.path_tools.get_path(dir_scmoc,time2,dh)
        sta = mpd.application.read_stadata_from_griddata(para,path,station_city)
        if(sta is not None):
            meb.set_stadata_coords(sta,time = time2,dtime = dh,level = 0)
            meb.set_stadata_names(sta,["gmosrr"])
            scmoc_list.append(sta)
    time2 = time2 + datetime.timedelta(hours = 12)
scmoc= pd.concat(scmoc_list,axis = 0)
scmoc.to_hdf(r"H:\test_data\input\mpd\time_compair\scmoc_rian03.h5","df")
# Out:
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.003.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.006.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.009.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.012.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.015.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.018.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.021.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.024.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.027.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.030.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.033.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.036.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.039.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.042.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.045.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.048.nc
# O:/data/grid/NWFD_SCMOC\RAIN03/20200408/20040808.051.nc
# ...

# %%
grapes1 = meb.sele_by_para(grapes,id = 54511)
grapes.to_hdf(r"H:\test_data\input\mpd\time_compair\grapes_t2m.h5","df")

# %%
station_city

# %%
#读取观测数据
dir_ob = r"SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION\YYYYMMDDHH0000.000"
ob_list = []
time2 = time1
station_city["data0"] = 0
while time2 <= now:
    path = meb.tool.path_tools.get_path(dir_ob,time2)
    sta = mpd.application.read_stadata(para,path,station = station_city)
    meb.set_stadata_names(sta,["ob"])
    ob_list.append(sta)
    time2 = time2 + datetime.timedelta(hours = 1)
ob_all = pd.concat(ob_list,axis = 0)
ob_all.to_hdf(r"H:\test_data\input\mpd\time_compair\ob_rain01.h5","df")
# Out:
# s:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# O:/data/sta/SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION/20200408/20200408080000.000
# O:/data/sta/SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION/20200408/20200408090000.000
# O:/data/sta/SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION/20200408/20200408100000.000
# O:/data/sta/SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION/20200408/20200408110000.000
# O:/data/sta/SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION/20200408/20200408120000.000
# O:/data/sta/SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION/20200408/20200408130000.000
# O:/data/sta/SURFACE\QC_BY_FSOL\RAIN01_ALL_STATION/20200408/20200408140000.000
# ...

# %%
rain03 = meb.rain_accumulate(ob_all,3)

# %%
rain03
# Out:
#      level                time  dtime     id     lon    lat   ob
# 0      0.0 2020-04-08 09:00:00      0  57842  109.72  26.88  0.0
# 1      0.0 2020-04-08 10:00:00      0  57842  109.72  26.88  0.0
# 2      0.0 2020-04-08 11:00:00      0  57842  109.72  26.88  0.0
# 3      0.0 2020-04-08 12:00:00      0  57842  109.72  26.88  0.0
# 4      0.0 2020-04-08 13:00:00      0  57842  109.72  26.88  0.0
# ..     ...                 ...    ...    ...     ...    ...  ...
# 175    0.0 2020-04-15 16:00:00      0  57842  109.72  26.88  0.0
# 176    0.0 2020-04-15 17:00:00      0  57842  109.72  26.88  0.0
# 177    0.0 2020-04-15 18:00:00      0  57842  109.72  26.88  0.0
# 178    0.0 2020-04-15 19:00:00      0  57842  109.72  26.88  0.0
# 179    0.0 2020-04-15 20:00:00      0  57842  109.72  26.88  0.0
#
# [180 rows x 7 columns]

# %%
sta_all = meb.combine_on_obTime_id(rain03,[scmoc])

# %%
mpd.time_list_mesh_rain03h(sta_all,s ={"time_range":["2020040820","2020041120"]})
