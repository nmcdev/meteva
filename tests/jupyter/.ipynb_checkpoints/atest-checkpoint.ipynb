# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import meteva.base as meb
import meteva.method as mem
import meteva.product as mpd
import numpy as np
import datetime
import copy
import matplotlib.pyplot as plt
import pandas as pd

# %%
sta = meb.read_stadata_from_micaps1_2_8(r"H:/20051506.000",8)
# Out:
#           0       1      2   8
# 0     50136  122.51  52.97  12
# 1     50137  122.38  53.47  12
# 2     50246  124.72  52.35  12
# 3     50247  123.57  52.04  12
# 4     50349  124.39  51.67  12
# ...     ...     ...    ...  ..
# 2408  59941  109.52  18.77  19
# 2409  59945  109.70  18.65  19
# 2410  59948  109.59  18.22  16
# 2411  59951  110.33  18.80  19
# 2412  59954  110.03  18.55  19
#
# [2413 rows x 4 columns]

# %%
veri_day_count = 7
time1 = today - datetime.timedelta(days = veri_day_count)
ob_list = []
for i in range(veri_day_count):
    time2 = time1 + datetime.timedelta(days = i)
    path = meb.tool.path_tools.get_path(dir_ob,time2)
    sta = mep.application.read_stadata(para,path,meb.gds_element_id.降水_24小时,station)
    ob_list.append(sta)
# Out:
#       level                time  dtime     id     lon    lat  data0
# 0         0 2020-05-15 06:00:00      0  50136  122.51  52.97   12.0
# 1         0 2020-05-15 06:00:00      0  50137  122.38  53.47   12.0
# 2         0 2020-05-15 06:00:00      0  50246  124.72  52.35   12.0
# 3         0 2020-05-15 06:00:00      0  50247  123.57  52.04   12.0
# 4         0 2020-05-15 06:00:00      0  50349  124.39  51.67   12.0
# ...     ...                 ...    ...    ...     ...    ...    ...
# 2408      0 2020-05-15 06:00:00      0  59941  109.52  18.77   19.0
# 2409      0 2020-05-15 06:00:00      0  59945  109.70  18.65   19.0
# 2410      0 2020-05-15 06:00:00      0  59948  109.59  18.22   16.0
# 2411      0 2020-05-15 06:00:00      0  59951  110.33  18.80   19.0
# 2412      0 2020-05-15 06:00:00      0  59954  110.03  18.55   19.0
#
# [2413 rows x 7 columns]

# %%
import json
import pandas as pd
f = open(r"H:\task\develop\java\OAL\等值面测试数据\test_05_sta.json", encoding='utf-8') 
setting = json.load(f)
dict1= setting["data"]["gisRainList"]
sta0 = pd.DataFrame(dict1)
sta0
# Out:
#     stationId stationName      lon      lat city county province  rain1  \
# 0       P3547          中洲  113.016  29.1339  岳阳市    岳阳县      湖南省    0.0
# 1       P3631       伍家洞水库  113.306  29.4083  岳阳市   岳阳楼区      湖南省    0.0
# 2       P3512          伍市  113.243  28.7497  岳阳市    平江县      湖南省    0.0
# 3       P3562         宋家嘴  112.479  29.4806  岳阳市    华容县      湖南省    0.0
# 4       P3605       屈原行政区  112.902  28.8606  岳阳市    汨罗市      湖南省    0.0
# ..        ...         ...      ...      ...  ...    ...      ...    ...
# 224     P3116          安定  113.664  28.5819  岳阳市    平江县      湖南省    8.3
# 225     P3580          湘滨  112.683  28.7419  岳阳市    湘阴县      湖南省    6.2
# 226     P3124        秋湖水库  113.598  28.5569  岳阳市    平江县      湖南省   12.0
# 227     P3120          三市  113.707  28.6439  岳阳市    平江县      湖南省   19.2
# 228     P3101        白水水库  113.711  28.4875  岳阳市    平江县      湖南省   27.9
#
#      rain3  rain6  rain12  rain24   val
# 0      0.0    0.0     0.0     0.0  None
# ...

# %%
sta1 = sta0[["stationId","lon","lat","rain24"]]
columns = sta1.columns.tolist()
columns[0] = "id"
sta2 = meb.sta_data(sta1,columns)
meb.write_stadata_to_micaps3(sta2,r"H:\task\develop\java\OAL\等值面测试数据\test05_sta.m3.txt")
# Out:
# True

# %%
sta3 = sta2[["lon","lat","rain24"]]
sta3.to_csv(r"H:\task\develop\java\OAL\等值面测试数据\test05_sta.txt",header = 0,index = 0)

# %%
import shutil

dir_input = r"L:\wuhan_data\laps\wind\850\YYMMDDHH.txt"
dir_output = r"L:\wuhan_data\laps\wind\850_f\YYMMDDHH.TTT"

dir_input = r"L:\wuhan_data\micaps\ws_result\shear_850_new_laps\YYMMDDHH.txt"
dir_output = r"L:\wuhan_data\micaps\ws_result\shear_850_new_laps_f\YYMMDDHH.TTT"

dir_input = r"L:\wuhan_data\micaps\rain01\ob\YYMMDDHH.000"
dir_output = r"L:\wuhan_data\micaps\rain01\ob_f\YYMMDDHH.TTT"

time0 = datetime.datetime(2019,6,5,0,0)
time1 = datetime.datetime(2019,6,6,0,0)
while time0 < time1:
    for dh in range(13):
        path_out = meb.get_path(dir_output,time0,dh)
        time2 = time0 +datetime.timedelta(hours = dh+8)
        path_in = meb.get_path(dir_input,time2)
        shutil.copyfile(path_in,path_out)
    time0 = time0+ datetime.timedelta(hours = 1)
