# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import nmc_verification.nmc_vf_base as nvb
import matplotlib.pyplot as plt

# %% [markdown]
# 程序库集成的各种要素自定义的等级和填色设置，其调用方式和效果如下：

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_temper_2m()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_rain_1h()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_rain_1h_error()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_rain_3h()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_rain_3h_error()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_rain_24h()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_rh()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_rh_error()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_vis()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
import numpy as np
clev,cmap = nvb.tool.color_tools.clev_cmap_vis_error()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_wind_speed()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_wind_speed_error()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_cloud_total()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)

# %%
clev,cmap = nvb.tool.color_tools.clev_cmap_cloud_total_error()
nvb.tool.color_tools.show_cmap_clev(cmap,clev)
