# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import meteva.method as mem
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ***通过随机函数生成测试数据，用于后续检验函数调用示例***

# %%
ob = (np.random.rand(20) * 10).astype(np.int8)
fo = (np.random.rand(8,20) * 10).astype(np.int8)
grade_list = [3,5]

# %%
ob
# Out:
# array([6, 5, 4, 0, 4, 8, 7, 0, 6, 8, 1, 7, 9, 4, 9, 7, 9, 7, 6, 5],
#       dtype=int8)

# %%
fo
# Out:
# array([[0, 3, 8, 5, 0, 6, 4, 3, 8, 2, 3, 3, 2, 5, 5, 6, 1, 8, 8, 8],
#        [5, 5, 7, 0, 5, 0, 1, 7, 0, 1, 1, 1, 8, 9, 3, 4, 5, 5, 3, 8],
#        [4, 4, 6, 2, 1, 0, 4, 0, 1, 3, 6, 5, 3, 2, 7, 8, 2, 1, 9, 7],
#        [7, 6, 6, 2, 0, 0, 7, 8, 7, 1, 7, 1, 8, 8, 7, 8, 4, 2, 7, 8],
#        [0, 0, 5, 5, 1, 9, 6, 8, 2, 2, 4, 7, 7, 4, 3, 4, 6, 2, 1, 6],
#        [2, 7, 6, 3, 2, 2, 0, 4, 8, 0, 9, 5, 6, 4, 1, 2, 0, 8, 2, 5],
#        [5, 2, 3, 9, 7, 7, 5, 2, 6, 3, 9, 8, 2, 0, 5, 4, 3, 6, 2, 2],
#        [5, 4, 8, 2, 1, 3, 2, 6, 6, 2, 2, 6, 4, 7, 0, 9, 2, 4, 8, 4]],
#       dtype=int8)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>频率统计图</font>**
# **frequency_histogram(ob, fo,grade_list=None,member_list=None, vmax = None, save_path=None，show = False,dpi = 300,title="频率统计图")**
# 统计观测和预报分别为各种类别的样本数,并以柱状图形式绘制成图片
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>ob</font>**|实况数据, 任意维numpy数组|
# |**<font face="黑体" color=blue size=5>fo</font>**|预测数据, 任意维numpy数组,Fo.shape 比Ob.shape多一维或者保持一致，Fo.shape低维与ob.shape保持一致|
# |**grade_list**| 如果该参数为None，观测或预报值出现过的值都作为分类标记，如果该参数不为None，它必须是一个从小到大排列的实数，以其中列出的数值划分出的多个区间作为分类标签。对于预报和观测值不为整数的情况，grade_list 不能设置为None|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**vmax**| 绘图窗口y轴方向最大值，通常在绘制单张图形时无需设置，在批量绘制多张该检验图时为了方便保持不同图片之间的可对比性，可以统一设置该参数|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#
# **调用示例：**

# %%
mem.frequency_histogram(ob, fo[0,:],member_list = ["ECMWF"]) # 输入的预报和观测shape一致

# %%
mem.frequency_histogram(ob, fo) #预报比观测高出一维，未设置member_list 时自动生成

# %%
#指定了多分类等级划分方式
mem.frequency_histogram(ob, fo,grade_list = grade_list,
                save_path = r"H:\test_data\output\method\multi_catagory\bar3.png",show = True)
# Out:
# 检验结果已以图片形式保存至H:\test_data\output\method\multi_catagory\bar3.png
