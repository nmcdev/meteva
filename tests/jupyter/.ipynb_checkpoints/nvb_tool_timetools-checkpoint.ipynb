# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import nmc_verification.nmc_vf_base as nvb
import datetime
import numpy as np

# %% [markdown]
# 在python编程中，经常涉及到datetime,numpy.datetime64和字符型的时间之间的转换问题。本程序库对此进行了进一步的封装。

# %% [markdown]
# # 转换为datetime.datetime类型
# **all_type_time_to_datetime(time0)**
# 将任意类型的时间转换为python中detetime.datetime类型
#
#
# **参数说明：**
#  **time0**: 字符型或datetime.datetime类型或numpy.datetime64类型的时间变量
#  **return**: datetime.datetime类型变量
#
#
#  **调用示例：**

# %%
time_str0 = "2019123108"
datetime1 = nvb.all_type_time_to_datetime(time_str0)
print(datetime1)
# Out:
# 2019-12-31 08:00:00

# %%
datetime0 = datetime.datetime(2019,12,31,8,0)
datetime1 = nvb.all_type_time_to_datetime(datetime0)
print(datetime1)
# Out:
# 2019-12-31 08:00:00

# %%
datetime64_0 = np.datetime64('2019-12-31T08:00:00.000000')
datetime1 = nvb.all_type_time_to_datetime(datetime0)
print(datetime1)
# Out:
# 2019-12-31 08:00:00

# %% [markdown]
# # 转换为numpy.datetime64类型
# **all_type_time_to_datetime(time0)**
# 将任意类型的时间转换为numpy.datetime64类型
#
#
# **参数说明：**
#  **time0**: 字符型或datetime.datetime类型或numpy.datetime64类型的时间变量
#  **return**: numpy.datetime64类型变量
#
#
#  **调用示例：**

# %%
datetime64_1 = nvb.all_type_time_to_time64(time_str0)
print(datetime64_1)
# Out:
# 2019-12-31T08:00:00.000000

# %%
datetime64_1 = nvb.all_type_time_to_time64(datetime0)
print(datetime64_1)
# Out:
# 2019-12-31T08:00:00.000000

# %%
datetime64_1 = nvb.all_type_time_to_time64(datetime64_0)
print(datetime64_1)
# Out:
# 2019-12-31T08:00:00.000000

# %% [markdown]
# # 转换为仅包含数字的字符串
# **all_type_time_to_datetime(time0)**
# 将任意类型的时间转换为仅包含数字的字符串
#
#
# **参数说明：**
#  **time0**: 字符型或datetime.datetime类型或numpy.datetime64类型的时间变量
#  **return**: 字符串
#
#
#  **调用示例：**

# %%
time_str1 = nvb.all_type_time_to_str(time_str0)
print(time_str1)
# Out:
# 20191231080000

# %%
time_str1 = nvb.all_type_time_to_str(datetime0)
print(time_str1)
# Out:
# 20191231080000

# %%
time_str1 = nvb.all_type_time_to_str(datetime64_0)
print(time_str1)
# Out:
# 20191231080000

# %% [markdown]
# # 时间差转换为numpy.timedelta64类型
# **all_type_timedelta_to_datetime(time0)**
# 将时间差转换为numpy.timedelta64类型
#
#
# **参数说明：**
#  **time0**: 字符型或datetime.timedelta类型或numpy.timedelta64类型的时间变量
#  **return**: numpy.timedelta64类型变量
#
#
#  **调用示例：**

# %%
dtime_str0 = "12h"
timedelta = nvb.all_type_timedelta_to_timedelta64(dtime_str0)
print(timedelta)
# Out:
# 43200000000 microseconds

# %%
dtime64 = nvb.all_type_timedelta_to_timedelta64(timedelta)
print(dtime64)
# Out:
# 43200000000 microseconds

# %%
dtime64 = nvb.all_type_timedelta_to_timedelta64(datetime.timedelta(hours = 24))
print(dtime64)
# Out:
# 86400000000 microseconds

# %% [markdown]
# # 时间差转换为datetime.timedelta类型
# **all_type_timedelta_to_datetime(time0)**
# 将时间差转换为datetime.timedelta类型
#
#
# **参数说明：**
#  **time0**: 字符型或datetime.timedelta类型或numpy.timedelta64类型的时间变量
#  **return**: datetime.timedelta类型变量
#
#
#  **调用示例：**

# %%
dtime1 = nvb.all_type_timedelta_to_timedelta(dtime64)
print(dtime1)
# Out:
# 1 day, 0:00:00

# %%
dtime1 = nvb.all_type_timedelta_to_timedelta("24h")
print(dtime1)
# Out:
# 1 day, 0:00:00

# %%
dtime1 = nvb.all_type_timedelta_to_timedelta(datetime.timedelta(hours = 24))
print(dtime1)
# Out:
# 1 day, 0:00:00
