# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import meteva.method as mem
import numpy as np
import copy
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ***通过随机函数生成测试数据，用于后续检验函数调用示例***

# %%
fo1 = np.random.rand(1000)
error = np.random.rand(1000)-0.5
ob = fo1 + error
ob[ob>0.5] = 1
ob[ob<=0.5] = 0
fo = np.array([fo1-0.1,fo1,fo1+0.1,fo1+0.3])
fo_name_list = ["ECMWF","NCEP","T639","GRAPES"]

# %% [markdown]
# **<font face="黑体" color=blue size = 5>区分能力图</font>**
# **discrimination(Ob, Fo, grade_count=10,member_list=None,  vmax = None, save_path=None,show = False,dpi = 300, title="区分能力图")**
# 绘制预报概率为不同区间下观测样本事件发生和不发生的样本占总样本的比例。
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>ob</font>**|实况数据, 任意维numpy数组|
# |**<font face="黑体" color=blue size=5>fo</font>**|预测数据, 任意维numpy数组,Fo.shape 比Ob.shape多一维或者保持一致，Fo.shape低维与ob.shape保持一致|
# |**grade_count**| 区分等级数 大于1的整数，它0 - 1 的概率预报区间划分为grade_count等分。缺省值为10|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**vmax**| 绘图窗口y轴方向最大值，通常在绘制单张图形时无需设置，在批量绘制多张该检验图时为了方便保持不同图片之间的可对比性，可以统一设置该参数|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#
#
#  **调用示例：**

# %%
mem.discrimination(ob,fo[1,:])

# %%
mem.discrimination(ob,fo,member_list = fo_name_list)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>ROC图</font>**
# **roc(Ob, Fo, grade_count=10, member_list=None, save_path=None,show = False,dpi = 300, title="ROC图")**
# 绘制ROC曲线，曲线以空报率（pofd）作为横坐标，以命中率（pod）为纵坐标。其中曲线描点为预报概率设置不同阈值作为预报发生的条件下，对应的（空报率，命中率）。
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>ob</font>**|实况数据, 任意维numpy数组|
# |**<font face="黑体" color=blue size=5>fo</font>**|预测数据, 任意维numpy数组,Fo.shape 比Ob.shape多一维或者保持一致，Fo.shape低维与ob.shape保持一致|
# |**grade_count**| 区分等级数 大于1的整数，它0 - 1 的概率预报区间划分为grade_count等分。缺省值为10|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#  **调用示例：**

# %%
mem.roc(ob,fo[2,:])

# %%
mem.roc(ob,fo,member_list = fo_name_list)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>可靠性图</font>**
# **reliability(Ob, Fo, grade_count=10, member_list=None,vmax = None, save_path=None,show = False,dpi = 300, title="可靠性图")**
# 绘制可靠性图，其中横坐标为预报概率。纵向分为主次两幅子图，主图纵坐标为同一预报概率区间下实况样本事件发生的比例。次图为每个预报区间对应的预报样本数。
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>ob</font>**|实况数据, 任意维numpy数组|
# |**<font face="黑体" color=blue size=5>fo</font>**|预测数据, 任意维numpy数组,Fo.shape 比Ob.shape多一维或者保持一致，Fo.shape低维与ob.shape保持一致|
# |**grade_count**| 区分等级数 大于1的整数，它0 - 1 的概率预报区间划分为grade_count等分。缺省值为10|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**vmax**| 绘图窗口样本数子图的y轴方向最大值，通常在绘制单张图形时无需设置，在批量绘制多张该检验图时为了方便保持不同图片之间的可对比性，可以统一设置该参数|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#
#  **调用示例：**

# %%
mem.reliability(ob,fo,member_list = fo_name_list)

# %% [markdown]
# 在可靠性图的计算和绘制过程中，如果某个区间的预报样本数为0，则会出现除0的情况，该区间对应的观测比例值为缺失值，此时程序会默认以虚线以线性插值的方式连接线条连接临近的描点，并在图中绘制×表示其缺失值。以下为效果示例：

# %%
index = np.where((fo[0,:] >=0.3) &(fo[0,:] <= 0.5)) 
fo_iv = copy.deepcopy(fo)
fo_iv[0,index[0]] += 0.2    #故意将某些区间的样本移动其它区间上
mem.reliability(ob,fo_iv,member_list = fo_name_list)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>综合检验图</font>**
# **def comprehensive_probability(Ob, Fo, grade_count=10, member_list=None,vmax = None,save_path=None,dpi = 300,show = False, title="概率预报综合检验图")**
# 可靠性图、ROC图和区分能力图的组合图。
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>ob</font>**|实况数据, 任意维numpy数组|
# |**<font face="黑体" color=blue size=5>fo</font>**|预测数据, 任意维numpy数组,Fo.shape 比Ob.shape多一维或者保持一致，Fo.shape低维与ob.shape保持一致|
# |**grade_count**| 区分等级数 大于1的整数，它0 - 1 的概率预报区间划分为grade_count等分。缺省值为10|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**vmax**| 绘图窗口样本数子图的y轴方向最大值，通常在绘制单张图形时无需设置，在批量绘制多张该检验图时为了方便保持不同图片之间的可对比性，可以统一设置该参数|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#
#  **调用示例：**

# %%
mem.comprehensive_probability(ob,fo,save_path = r"H:\test_data\output\method\probability\p3.png",show = True)
# Out:
# 检验结果已以图片形式保存至H:\test_data\output\method\probability\p3.png

# %% [markdown]
# 在以上示例中，观测和预报的数据都直接输入到评分函数中进行计算，然而有些情况下待检验的数据太大不能整体存入一个numpy数组中，或者不方便整体存入一个numpy数组中，此时就不能调用上面的方式调用评分函数。为此本程序库设计了一套可分块计算的检验程序。
# 其检验步骤如下：
# 步骤1：根据需要将分块数据逐一输入到中间结果计算函数
# 步骤2：将中间结果进行累加或合并
# 步骤3：根据累加或合并的中间结果计算检验指标
# 通常上述计算中步骤1是最耗费计算资源，为了提高效率步骤1也可以采用并行的方式执行。此外，步骤1执行的结果也可输出到文件中，在后续的检验可以从中读入部分中间结果执行后续步骤，从而可以实现各种方式的分组检验，大大提高检验计算效率。
# 对于概率预报的检验来说，涉及的中间结果统计函数为[mem.hnh](https://www.showdoc.cc/meteva?page_id=4680093808004082)
# **调用示例：**

# %%
hnh_array1 = mem.hnh(ob,fo1,10)
hnh_array1.shape
# Out:
# (10, 2)

# %%
hnh_array2 = mem.hnh(ob,fo,10)
hnh_array2.shape
# Out:
# (4, 10, 2)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>区分能力图</font>**
# **discrimination_hnh(hnh_array,  member_list=None, vmax = None,save_path=None,show = False,dpi = 300, title="区分能力图")**
# 绘制预报概率为不同区间下观测样本事件发生和不发生的样本占总样本的比例。
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>hnh_array</font>**|区分能力表，大于或等于2维的数组，其中最后一维size = 2，倒数第二维size = grade_cont(等级数)，更高的维度代表不同成员的预报或者不同分组预报对应的统计结果|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**vmax**| 绘图窗口样本数子图的y轴方向最大值，通常在绘制单张图形时无需设置，在批量绘制多张该检验图时为了方便保持不同图片之间的可对比性，可以统一设置该参数|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#
#  **调用示例：**

# %%
mem.discrimination_hnh(hnh_array1)

# %%
mem.discrimination_hnh(hnh_array2)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>ROC图 </font>**
# **roc_hnh(hnh_array,  member_list=None, save_path=None,show  =False, dpi = 300, title="ROC图")**
# 绘制ROC曲线，曲线以空报率（pofd）作为横坐标，以命中率（pod）为纵坐标。其中曲线描点为预报概率设置不同阈值作为预报发生的条件下，对应的（空报率，命中率）。
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>hnh_array</font>**|区分能力表，大于或等于2维的数组，其中最后一维size = 2，倒数第二维size = grade_cont(等级数)，更高的维度代表不同成员的预报或者不同分组预报对应的统计结果|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#  **调用示例：**

# %%
mem.roc_hnh(hnh_array1)

# %%
mem.roc_hnh(hnh_array2)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>可靠性图</font>**
# **reliability_hnh(hnh_array, member_list=None,vmax = None, save_path=None,show = False,dpi = 300, title="可靠性图")**
# 绘制可靠性图，其中横坐标为预报概率。纵向分为主次两幅子图，主图纵坐标为同一预报概率区间下实况样本事件发生的比例。次图为每个预报区间对应的预报样本数。
#
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>hnh_array</font>**|区分能力表，大于或等于2维的数组，其中最后一维size = 2，倒数第二维size = grade_cont(等级数)，更高的维度代表不同成员的预报或者不同分组预报对应的统计结果|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**vmax**| 绘图窗口样本数子图的y轴方向最大值，通常在绘制单张图形时无需设置，在批量绘制多张该检验图时为了方便保持不同图片之间的可对比性，可以统一设置该参数|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#
#
#  **调用示例：**

# %%
mem.reliability_hnh(hnh_array1)

# %%
mem.reliability_hnh(hnh_array2)

# %% [markdown]
# **<font face="黑体" color=blue size = 5>综合检验图</font>**
# **comprehensive_hnh(hnh_array, member_list=None,vmax = None, save_path=None,show = False,dpi = 300, title="概率预报综合检验图")**
# 可靠性图、ROC图和区分能力图的组合图。
#
# |参数|说明|
# |:--|:--|
# |**<font face="黑体" color=blue size=5>hnh_array</font>**|区分能力表，大于或等于2维的数组，其中最后一维size = 2，倒数第二维size = grade_cont(等级数)，更高的维度代表不同成员的预报或者不同分组预报对应的统计结果|
# |**member_list**|个预报成员的名称列表，缺省时系统由自动生成，将在bar图的legend中显示|
# |**vmax**| 绘图窗口样本数子图的y轴方向最大值，通常在绘制单张图形时无需设置，在批量绘制多张该检验图时为了方便保持不同图片之间的可对比性，可以统一设置该参数|
# |**save_path**| 图片保存路径，缺省时不输出图片，而是以默认绘图窗口形式展示 |
# |**show**| 是否在屏幕显示图片，如果save_path 和save_dir 为都None时，程序内部会自动将show设置True|
# |**dpi**| 绘图所采用dpi参数,效果同matplotlib中dpi参数|
# |**title**|图片标题，缺省时 为“散点回归图” |
# |**<font face="黑体" color=blue size=5>return</font>**|无返回结果|
#
#
#  **调用示例：**

# %%
mem.comprehensive_hnh(hnh_array1)

# %%
mem.comprehensive_hnh(hnh_array2)
